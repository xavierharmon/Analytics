# %%
import sys 
sys.path.append(r'C:\Users\HarmonX\Documents\deag-analytics\Python Scripts\custom-team-scripts')
import DEA_timeseries as ts
# Out:
# Thank you for using the Clayton DEA&G time series package.
#
# Please place the complete file path here with the file name for your dataset in .csv or .xlsx
# format.C:\Users\HarmonX\Documents\Projects\Examples\ColoradoHousingInv.csv
# What is the dependent (y) variable for your dataset?HousingInventory
# What is the time variable you wish to use for your model?Week
# What time frequency do you want for your output? Type MS for Monthly and W for weekly results. If
# your data is already aggregated to a weekly or monthly level please choose that option.ms
# You did not select a valid frequency, please use MS for monthly time series results and W for weekly results.
# What time frequency do you want for your output? Type MS for Monthly and W for weekly results. If
# your data is already aggregated to a weekly or monthly level please choose that option.MS
# How many periods into the future would you like to generate your forecast for? By default the
# ...

# %%
arima_model = ts.ARIMA()
# Out:
# You are running a dynamic ARIMA model with housinginventory as your dependent variable. You
# have chosen to group your data on the column metroarea, meaning one ARIMA model will be
# built for every metroarea. You should expect 3 result sets.
# Are you sure you wish to run the ARIMA seasonal model? If so type yes, otherwise press enter.yes
# How many periods do you wish to include for a seasonal trend in your data? For example, if you are
# using monthly data, 12 would be a yearly trend.12
#
# This function will output every combination of the seasonal and non-seasonal parameters with their
# Akaike Information Criterion (AIC). The AIC values are a test for the fit of the model and will be
# used to determine the optimal set of paramters. The AIC score aims to find the best fitting model
# for the data while avoiding over-fitting of the data set. The model with the lowest AIC value is the
# best fitting model.
#
# ...
