# %%
import sys 
sys.path.append(r'C:\Users\HarmonX\Documents\Projects\Examples\Time Series')
import multivariate_timeseries as ts
# Out:
# Thank you for using the Multivariate time series package.
#
# Please place the complete file path here with the file name for your dataset in .csv or .xlsx
# format.C:\Users\HarmonX\Documents\Projects\Examples\ZillowKnoxvilleData.csv
# What is the time variable you wish to use for your model?date
#  What time frequency do you want for your output? Type MS for Monthly and W for weekly results. If
# your data is already aggregated to a weekly or monthly level please choose that option.MS
#  By default your data will be averaged for use in this model, if you need to sum your input data
# please type sum here otherwise press enter to continue.
#  How many periods into the future would you like to generate your forecast for, by default the
# package has set this value to 12? Keep in mind the granularity of your data. Here 12 would be a year
# for monthly data while 52 would be a year for weekly data. Please use integers12
# ...

# %%
var = ts.vectorizedAR()
# Out:
# Are you sure you wish to continue with the Vectorized Auto-Regressive Time Series model? Type y for
# yes and press enter otherwise press enter to close the function.y
# metroarea
# date
# inventory
# medianlistprice
# newpending
# percentpricecut
# period
# year
#
# Your column names are listed above, one by one please enter the columns you wish to use for your
# Multivariate Time Series Model below.
#
# Enter next column name here and press enter otherwise press enter. If you wish to use all columns in
# your dataset please type All and hit enter.all
# C:\Users\HarmonX\Documents\Projects\Examples\Time Series\multivariate_timeseries.py:287: FutureWarning: The 'get_values' method is deprecated and will be removed in a future version. Use '.to_numpy()' or '.array' instead.
#   dfcolumns = allcoldf.columns.get_values()
# Your columns are ['inventory', 'medianlistprice', 'newpending', 'percentpricecut']
# ...
